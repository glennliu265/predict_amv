# %%
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
import os
import torch
from torch import nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# %%
path = '../../CESM_data/Metrics/'

# %%
fnames = []
for fname in os.listdir(path):
    if 'FNN2' in fname:
        fnames.append(fname)

# %%
fnames[0].split('_')[2]
# Out:
# 'ALL'

# %%
var = []
for fname in fnames:
    var.append(  fname.split('_')[2] )
    f = np.load(path+fname)
    plt.plot(f['test_percent'])
plt.legend(var)
