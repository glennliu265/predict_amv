# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import xarray as xr
import scipy
import os

# %%
sst = xr.open_dataset('../../CESM_data/CESM1LE_sst_NAtl_19200101_20051201_Regridded2deg.nc')
sss = xr.open_dataset('../../CESM_data/CESM1LE_sss_NAtl_19200101_20051201_Regridded2deg.nc')
psl = xr.open_dataset('../../CESM_data/CESM1LE_psl_NAtl_19200101_20051201_Regridded2deg.nc')

# %%
sst.mean(dim=('ensemble','time'))['sst'][0:33,5:46].plot(cmap='Spectral')

# %%
sss.mean(dim=('ensemble','time'))['sss'][0:33,5:46].plot()

# %%
psl.mean(dim=('ensemble','time'))['psl'][0:33,5:46].plot()
